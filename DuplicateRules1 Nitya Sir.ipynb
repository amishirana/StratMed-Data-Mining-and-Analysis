# %%
import numpy as np
import pandas as pd

# %%
x = pd.read_csv("stratmed_item_master23-05.csv")
x.count
# Out:
# C:\Users\nitya\AppData\Local\Temp\ipykernel_28932\1760801603.py:1: DtypeWarning: Columns (14,15,16,18,26,27,37,40,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   x = pd.read_csv("stratmed_item_master23-05.csv")
# <bound method DataFrame.count of         Unnamed: 0                       _id  stratmed_sku  brand_code  \
# 0                0  600875f616802c03e8ae78c0        100102         NaN
# 1                1  600875f616802c03e8ae78c2        100104         NaN
# 2                2  600875f616802c03e8ae78c3        100105         NaN
# 3                3  600875f616802c03e8ae78c4        100106         NaN
# 4                4  600875f616802c03e8ae78c5        100107         NaN
# ...            ...                       ...           ...         ...
# 271449      271449  627502c649d20bd26bc2f119        555950         NaN
# 271450      271450  6275031449d20bd26bc325de        555951         NaN
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
x
# Out:
#         Unnamed: 0                       _id  stratmed_sku  brand_code  \
# 0                0  600875f616802c03e8ae78c0        100102         NaN
# 1                1  600875f616802c03e8ae78c2        100104         NaN
# 2                2  600875f616802c03e8ae78c3        100105         NaN
# 3                3  600875f616802c03e8ae78c4        100106         NaN
# 4                4  600875f616802c03e8ae78c5        100107         NaN
# ...            ...                       ...           ...         ...
# 271449      271449  627502c649d20bd26bc2f119        555950         NaN
# 271450      271450  6275031449d20bd26bc325de        555951         NaN
# 271451      271451  6275033649d20bd26bc33ddd        555952         NaN
# 271452      271452  6275037549d20bd26bc36995        555953         NaN
# 271453      271453  627503c449d20bd26bc39fe9        555954         NaN
#
#                                    brand_name category  committed_volume  \
# ...

# %%
x1=x.apply(lambda x: x.astype(str).str.lower())
y = x1[['generic_name','form_name','dose_size','manufacturer_name','brand_name','unit_per_pack','mrp']]
y.to_csv("concatenated.csv")
y.count
# Out:
# <bound method DataFrame.count of                                              generic_name       form_name  \
# 0                                                 heparin       ointments
# 1                                                 heparin            gels
# 2       glycyrrhiza glabra+phyllanthus emblica+tinospo...         tablets
# 3                                           carica papaya         tablets
# 4                                            ademetionine         tablets
# ...                                                   ...             ...
# 271449                                       spinal drape  not applicable
# 271450                           endotracheal tube cuffed  not applicable
# 271451                           endotracheal tube cuffed  not applicable
# 271452                                    foleys catheter  not applicable
# 271453                               tracheal tube cuffed  not applicable
#
# ...

# %% [markdown]
# ##  duplicates

# %%
dup1 = y[y.duplicated(keep=False)]
dup1
dup1.to_csv("testduplicates2.csv")
dup1.count
# Out:
# <bound method DataFrame.count of                         generic_name       form_name     dose_size  \
# 943      amoxycillin+clavulanic acid      injections  1000mg+200mg
# 1152     amoxycillin+clavulanic acid      injections    250mg+50mg
# 1177     amoxycillin+clavulanic acid      injections   500mg+100mg
# 1322          ceftazidime+tazobactum      injections  1000mg+125mg
# 2643    ketoconazole+zinc pyrithione         lotions   2%w/v+1%w/v
# ...                              ...             ...           ...
# 270905              tibial linear ps  not applicable           9mm
# 270919  urgotul absorb border sacrum  not applicable       15x20cm
# 270922  urgotul absorb border sacrum  not applicable       10x25cm
# 271302           thermometer digital  not applicable           nan
# 271303           thermometer digital  not applicable           nan
#
#          manufacturer_name                                         brand_name  \
# ...
