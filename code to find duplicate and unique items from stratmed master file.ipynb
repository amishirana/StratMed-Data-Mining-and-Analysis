# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x= pd.read_csv('stratmed_item_master23-05.csv')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_21948\1277093868.py:1: DtypeWarning: Columns (14,15,16,18,26,27,37,38,40,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   x= pd.read_csv('stratmed_item_master23-05.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
x.head(10)
# Out:
#    Unnamed: 0                       _id  stratmed_sku  brand_code  \
# 0           0  600875f616802c03e8ae78c0        100102         NaN
# 1           1  600875f616802c03e8ae78c2        100104         NaN
# 2           2  600875f616802c03e8ae78c3        100105         NaN
# 3           3  600875f616802c03e8ae78c4        100106         NaN
# 4           4  600875f616802c03e8ae78c5        100107         NaN
# 5           5  600875f616802c03e8ae78c6        100108         NaN
# 6           6  600875f616802c03e8ae78c7        100109         NaN
# 7           7  600875f616802c03e8ae78c8        100111         NaN
# 8           8  600875f616802c03e8ae78c9        100112         NaN
# 9           9  600875f616802c03e8ae78ca        100113         NaN
#
#                brand_name category  committed_volume dose_size/strength  \
# 0  THROMBOPHOB 20 GM OINT   CAT100               NaN               50IU
# 1   THROMBOPHOB 20 GM GEL   CAT100               NaN              200IU
# ...

# %%
y = x[['generic_name','form','dose_size/strength','manufacturer_name','subcategory_name','unit_per_pack/UPP','mrp']]
y
# Out:
#                                              generic_name    form  \
# 0                                                 Heparin  FOR101
# 1                                                 Heparin  FOR103
# 2       Glycyrrhiza Glabra+phyllanthus Emblica+tinospo...  FOR102
# 3                                           Carica Papaya  FOR102
# 4                                            Ademetionine  FOR102
# ...                                                   ...     ...
# 271449                                       Spinal Drape  FOR154
# 271450                           Endotracheal Tube Cuffed  FOR154
# 271451                           Endotracheal Tube Cuffed  FOR154
# 271452                                    Foleys Catheter  FOR154
# 271453                               Tracheal Tube Cuffed  FOR154
#
#        dose_size/strength   manufacturer_name      subcategory_name  \
# 0                    50IU        ZYDUS CADILA  Cardiac & Hematinics
# ...

# %% [markdown]
# ## RULE 1

# %%
dup1 = y[y.duplicated()]
dup1
# Out:
#                  generic_name    form dose_size/strength manufacturer_name  \
# 23                 Filgrastim  FOR105             300MCG      INTAS PHARMA
# 62            Povidone-iodine  FOR106              2%W/V      WIN MEDICARE
# 159     Ibuprofen+paracetamol  FOR118      100MG+162.5MG             CIPLA
# 247               Paracetamol  FOR118              250MG        MICRO LABS
# 303               Paracetamol  FOR114              100MG   GLAXOSMITHKLINE
# ...                       ...     ...                ...               ...
# 271265            Vessel Loop  FOR154                NaN            PRYMAX
# 271298              Telescope  FOR154                NaN        KARL STORZ
# 271303    Thermometer Digital  FOR154                NaN             LOCAL
# 271411  Skin Care Preparation  FOR113               Null       USV PVT LTD
# 271443             Metoprolol  FOR102               50MG       ASTRAZENECA
#
#                  subcategory_name  unit_per_pack/UPP       mrp
# ...

# %% [markdown]
# # List of Duplicates items

# %%
x = x.loc[dup1.index, :]

# %%
dup1.to_csv('rule1.csv')

# %% [markdown]
# # Rule 2 :Not Duplicate products

# %%
dup2 = y[y.duplicated(['form','dose_size/strength','manufacturer_name','unit_per_pack/UPP','mrp'])]
dup2
# Out:
#                  generic_name    form dose_size/strength manufacturer_name  \
# 23                 Filgrastim  FOR105             300MCG      INTAS PHARMA
# 62            Povidone-iodine  FOR106              2%W/V      WIN MEDICARE
# 121             Nipple Shield  FOR100                NaN      ARDO MEDICAL
# 159     Ibuprofen+paracetamol  FOR118      100MG+162.5MG             CIPLA
# 247               Paracetamol  FOR118              250MG        MICRO LABS
# ...                       ...     ...                ...               ...
# 271333           WATER BOTTLE  FOR154                NaN             LOCAL
# 271359              Under Pad  FOR154              LARGE             LOCAL
# 271411  Skin Care Preparation  FOR113               Null       USV PVT LTD
# 271443             Metoprolol  FOR102               50MG       ASTRAZENECA
# 271446        Surgical Drapes  FOR154                NaN        MEDI KARMA
#
#                  subcategory_name  unit_per_pack/UPP      mrp
# ...

# %% [markdown]
# ## Rule 2: Not Duplicate

# %%
dup2=dup2.drop_duplicates(['generic_name','subcategory_name'],keep='last')
dup2
# Out:
#                  generic_name    form dose_size/strength manufacturer_name  \
# 23                 Filgrastim  FOR105             300MCG      INTAS PHARMA
# 62            Povidone-iodine  FOR106              2%W/V      WIN MEDICARE
# 121             Nipple Shield  FOR100                NaN      ARDO MEDICAL
# 159     Ibuprofen+paracetamol  FOR118      100MG+162.5MG             CIPLA
# 435                 Ibuprofen  FOR118              100MG             CIPLA
# ...                       ...     ...                ...               ...
# 271333           WATER BOTTLE  FOR154                NaN             LOCAL
# 271359              Under Pad  FOR154              LARGE             LOCAL
# 271411  Skin Care Preparation  FOR113               Null       USV PVT LTD
# 271443             Metoprolol  FOR102               50MG       ASTRAZENECA
# 271446        Surgical Drapes  FOR154                NaN        MEDI KARMA
#
#                  subcategory_name  unit_per_pack/UPP      mrp
# ...

# %%
dup2.to_csv('rule2.csv')

# %% [markdown]
# # Rule 3 Not Duplicate records.

# %%
dup3 = y[y.duplicated(['generic_name','form','dose_size/strength','manufacturer_name','subcategory_name','mrp'])]
dup3
# Out:
#                  generic_name    form dose_size/strength manufacturer_name  \
# 23                 Filgrastim  FOR105             300MCG      INTAS PHARMA
# 62            Povidone-iodine  FOR106              2%W/V      WIN MEDICARE
# 159     Ibuprofen+paracetamol  FOR118      100MG+162.5MG             CIPLA
# 247               Paracetamol  FOR118              250MG        MICRO LABS
# 303               Paracetamol  FOR114              100MG   GLAXOSMITHKLINE
# ...                       ...     ...                ...               ...
# 271265            Vessel Loop  FOR154                NaN            PRYMAX
# 271298              Telescope  FOR154                NaN        KARL STORZ
# 271303    Thermometer Digital  FOR154                NaN             LOCAL
# 271411  Skin Care Preparation  FOR113               Null       USV PVT LTD
# 271443             Metoprolol  FOR102               50MG       ASTRAZENECA
#
#                  subcategory_name  unit_per_pack/UPP       mrp
# ...

# %%
dup3=dup3.drop_duplicates('unit_per_pack/UPP',keep='last')
dup3
# Out:
#                                              generic_name    form  \
# 6151                                           Ticagrelor  FOR102
# 33028                                           Tadalafil  FOR137
# 35111                         Pentosan Polysulfate Sodium  FOR109
# 51252                             Etofylline+theophylline  FOR149
# 51322                             Etofylline+theophylline  FOR149
# 112313                                       Azithromycin  FOR137
# 123096                                           Nicotine  FOR137
# 129694                              Glimepiride+metformin  FOR137
# 173700                                       Levofloxacin  FOR137
# 175295                            Metformin+teneligliptin  FOR137
# 177023                                          Thyroxine  FOR137
# 177785                 Alendronic Acid+calcium+vitamin D3  FOR137
# 189739                                         Sildenafil  FOR137
# ...

# %%
dup3.to_csv('rule3.csv')

# %% [markdown]
# # Rule 4: Not Duplicate records.

# %%
dup4 = y[y.duplicated(['generic_name','form','manufacturer_name','subcategory_name','unit_per_pack/UPP','mrp'])]
dup4
# Out:
#                         generic_name    form dose_size/strength  \
# 23                        Filgrastim  FOR105             300MCG
# 62                   Povidone-iodine  FOR106              2%W/V
# 94      Choline Salicylate+Lidocaine  FOR103                  0
# 159            Ibuprofen+paracetamol  FOR118      100MG+162.5MG
# 247                      Paracetamol  FOR118              250MG
# ...                              ...     ...                ...
# 271360                     Under Pad  FOR154                 XL
# 271411         Skin Care Preparation  FOR113               Null
# 271415          Silicon Ring Pessary  FOR154               75MM
# 271443                    Metoprolol  FOR102               50MG
# 271451      Endotracheal Tube Cuffed  FOR154                8MM
#
#        manufacturer_name           subcategory_name  unit_per_pack/UPP  \
# 23          INTAS PHARMA            Anti-Infectives                  1
# ...

# %%
dup4['dose_size/strength'].value_counts()
# Out:
# Feb-00                        188
# Not Applicable                139
# 100MG                         135
# MEDIUM                        119
# Null                          108
#                              ...
# PGLA VIO 0 X 135 (45X3)         1
# PGLA UND 0 X 75-40MM HC TC      1
# PGLA UND 0 X 90-36MM HC RB      1
# PGLA VIO 0 X 90-40MM HC BP      1
# 105MM                           1
# Name: dose_size/strength, Length: 3878, dtype: int64

# %%
dup4=dup4.drop_duplicates('dose_size/strength',keep='last')
dup4
# Out:
#                           generic_name    form dose_size/strength  \
# 159              Ibuprofen+paracetamol  FOR118      100MG+162.5MG
# 516                      Buprenorphine  FOR122             10MCG
# 592                        Ropivacaine  FOR105              0.002
# 864     Human Insulin+insulin Isophane  FOR105       [30/70]100IU
# 3518           Lactobacillus Rhamnosus  FOR110             6000MG
# ...                                ...     ...                ...
# 271360                       Under Pad  FOR154                 XL
# 271411           Skin Care Preparation  FOR113               Null
# 271415            Silicon Ring Pessary  FOR154               75MM
# 271443                      Metoprolol  FOR102               50MG
# 271451        Endotracheal Tube Cuffed  FOR154                8MM
#
#        manufacturer_name           subcategory_name  unit_per_pack/UPP     mrp
# 159                CIPLA  Analgesics & Antipyretics                  1   37.51
# ...

# %%
dup4.to_csv('rule4.csv')

# %%
dup4['dose_size/strength'].value_counts()
# Out:
# 100MG+162.5MG                1
# 11MM 18INCH                  1
# 4.9MMX70MM                   1
# 3.5MMX34MM                   1
# 125LTR                       1
#                             ..
# 16 FG                        1
# 24 FG                        1
# WITH STEINMANN PIN MEDIUM    1
# 10 G                         1
# 8MM                          1
# Name: dose_size/strength, Length: 3878, dtype: int64

# %%
dup4['dose_size/strength'].is_unique
# Out:
# True

# %%
dup4['dose_size/strength']= dup4['dose_size/strength'].value_counts().rename_axis('unique_values').to_frame('counts')
dup4
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3612\1369767269.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dup4['dose_size/strength']= dup4['dose_size/strength'].value_counts().rename_axis('unique_values').to_frame('counts')
#                           generic_name    form  dose_size/strength  \
# 159              Ibuprofen+paracetamol  FOR118                 NaN
# 516                      Buprenorphine  FOR122                 NaN
# 592                        Ropivacaine  FOR105                 NaN
# 864     Human Insulin+insulin Isophane  FOR105                 NaN
# 3518           Lactobacillus Rhamnosus  FOR110                 NaN
# ...                                ...     ...                 ...
# ...

# %%
dup4['dose_size/strength'].dtype
# Out:
# dtype('float64')

# %%
dup4[dup4['dose_size/strength']=='Null']
# Out:
# Empty DataFrame
# Columns: [generic_name, form, dose_size/strength, manufacturer_name, subcategory_name, unit_per_pack/UPP, mrp]
# Index: []

# %%
dup4=dup4[dup4['dose_size/strength']!='Null']
dup4
# Out:
#                           generic_name    form  dose_size/strength  \
# 159              Ibuprofen+paracetamol  FOR118                 NaN
# 516                      Buprenorphine  FOR122                 NaN
# 592                        Ropivacaine  FOR105                 NaN
# 864     Human Insulin+insulin Isophane  FOR105                 NaN
# 3518           Lactobacillus Rhamnosus  FOR110                 NaN
# ...                                ...     ...                 ...
# 271360                       Under Pad  FOR154                 NaN
# 271411           Skin Care Preparation  FOR113                 NaN
# 271415            Silicon Ring Pessary  FOR154                 NaN
# 271443                      Metoprolol  FOR102                 NaN
# 271451        Endotracheal Tube Cuffed  FOR154                 NaN
#
#        manufacturer_name           subcategory_name  unit_per_pack/UPP     mrp
# 159                CIPLA  Analgesics & Antipyretics                  1   37.51
# ...

# %% [markdown]
# # Rule 5: Duplicate records

# %%
dup5 = y[y.duplicated(['generic_name','form','dose_size/strength','manufacturer_name','subcategory_name','unit_per_pack/UPP'])]
dup5
# Out:
#                   generic_name    form dose_size/strength manufacturer_name  \
# 21                Ademetionine  FOR102              200MG        SUN PHARMA
# 22                Ademetionine  FOR102              400MG        SUN PHARMA
# 23                  Filgrastim  FOR105             300MCG      INTAS PHARMA
# 45      Nutritional Supplement  FOR110               15GM    FRESENIUS KABI
# 62             Povidone-iodine  FOR106              2%W/V      WIN MEDICARE
# ...                        ...     ...                ...               ...
# 271411   Skin Care Preparation  FOR113               Null       USV PVT LTD
# 271433       Absorbable Suture  FOR154             Jan-00           ETHICON
# 271443              Metoprolol  FOR102               50MG       ASTRAZENECA
# 271446         Surgical Drapes  FOR154                NaN        MEDI KARMA
# 271447         Surgical Drapes  FOR154                NaN        MEDI KARMA
#
# ...

# %%
dup5=dup5.drop_duplicates('mrp',keep='last')
dup5
# Out:
#                  generic_name    form dose_size/strength manufacturer_name  \
# 23                 Filgrastim  FOR105             300MCG      INTAS PHARMA
# 72                Toothpastes  FOR112                  0    DR REDDYS LABS
# 159     Ibuprofen+paracetamol  FOR118      100MG+162.5MG             CIPLA
# 285                  Etodolac  FOR102              400MG         IPCA LABS
# 334                Tapentadol  FOR102               50MG          MSN LABS
# ...                       ...     ...                ...               ...
# 271411  Skin Care Preparation  FOR113               Null       USV PVT LTD
# 271433      Absorbable Suture  FOR154             Jan-00           ETHICON
# 271443             Metoprolol  FOR102               50MG       ASTRAZENECA
# 271446        Surgical Drapes  FOR154                NaN        MEDI KARMA
# 271447        Surgical Drapes  FOR154                NaN        MEDI KARMA
#
#                  subcategory_name  unit_per_pack/UPP      mrp
# ...

# %%
dup5.to_csv('rule5.csv')

# %% [markdown]
# # Rule 6:Duplicate records

# %%
dup6 = y[y.duplicated(['generic_name','form','dose_size/strength','subcategory_name','unit_per_pack/UPP','mrp'])]
dup6
# Out:
#                  generic_name    form dose_size/strength manufacturer_name  \
# 23                 Filgrastim  FOR105             300MCG      INTAS PHARMA
# 62            Povidone-iodine  FOR106              2%W/V      WIN MEDICARE
# 117             Nipple Shield  FOR100                NaN            MEDELA
# 121             Nipple Shield  FOR100                NaN      ARDO MEDICAL
# 159     Ibuprofen+paracetamol  FOR118      100MG+162.5MG             CIPLA
# ...                       ...     ...                ...               ...
# 271362               Fentanyl  FOR105              50MCG             LOCAL
# 271411  Skin Care Preparation  FOR113               Null       USV PVT LTD
# 271438        Foleys Catheter  FOR154               10FR           POLYMED
# 271443             Metoprolol  FOR102               50MG       ASTRAZENECA
# 271447        Surgical Drapes  FOR154                NaN        MEDI KARMA
#
#                  subcategory_name  unit_per_pack/UPP      mrp
# ...

# %%
dup6=dup6.drop_duplicates('manufacturer_name',keep='last')
dup6
# Out:
#                                              generic_name    form  \
# 117                                         Nipple Shield  FOR100
# 121                                         Nipple Shield  FOR100
# 1590                                        Human Albumin  FOR121
# 2777    Betaine+ceramide+nitroglycerin+olea Europea+pa...  FOR138
# 3097                                      Petroleum Jelly  FOR103
# ...                                                   ...     ...
# 271362                                           Fentanyl  FOR105
# 271411                              Skin Care Preparation  FOR113
# 271438                                    Foleys Catheter  FOR154
# 271443                                         Metoprolol  FOR102
# 271447                                    Surgical Drapes  FOR154
#
#        dose_size/strength manufacturer_name                subcategory_name  \
# 117                   NaN            MEDELA             General Consumables
# ...

# %%
dup6.to_csv('rule6.csv')

# %% [markdown]
# # Rule 7:Not Duplicate records

# %%
dup7 = y[y.duplicated(['generic_name','form','dose_size/strength','manufacturer_name','unit_per_pack/UPP','mrp'])]
dup7
# Out:
#                  generic_name    form dose_size/strength manufacturer_name  \
# 23                 Filgrastim  FOR105             300MCG      INTAS PHARMA
# 62            Povidone-iodine  FOR106              2%W/V      WIN MEDICARE
# 159     Ibuprofen+paracetamol  FOR118      100MG+162.5MG             CIPLA
# 247               Paracetamol  FOR118              250MG        MICRO LABS
# 303               Paracetamol  FOR114              100MG   GLAXOSMITHKLINE
# ...                       ...     ...                ...               ...
# 271286                Sticker  FOR154                NaN             LOCAL
# 271298              Telescope  FOR154                NaN        KARL STORZ
# 271303    Thermometer Digital  FOR154                NaN             LOCAL
# 271411  Skin Care Preparation  FOR113               Null       USV PVT LTD
# 271443             Metoprolol  FOR102               50MG       ASTRAZENECA
#
#                  subcategory_name  unit_per_pack/UPP       mrp
# ...

# %%
dup7=dup7.drop_duplicates('subcategory_name',keep='last')
dup7
# Out:
#                                              generic_name    form  \
# 167137                                        Bupivacaine  FOR105
# 220374                            Stent Oesophageal Nitis  FOR150
# 225943                                      Kirchner Wire  FOR154
# 230458                                            T4 TEST  FOR154
# 233582                                        Hearing Aid  FOR154
# 238139                          Pressure Monitoring Lines  FOR154
# 238302                                  Tracheostemy Tube  FOR154
# 241649                                          Ultraflux  FOR154
# 244565                   CORONA VIRUS VACCINE RECOMBINANT  FOR105
# 250022                                Mouth Washes/rinses  FOR106
# 250903  Tlif Cage Juliet-r Tl Thoracic Lumber Dyn-tl04...  FOR154
# 251051                           D.J. Stent Both End Open  FOR154
# 251431                                       Gates Drills  FOR154
# ...

# %%
dup7.to_csv('rule7.csv')

# %% [markdown]
# # Rule 8: Duplicate records

# %%
dup8 = y[y.duplicated(['generic_name','dose_size/strength','manufacturer_name','subcategory_name','unit_per_pack/UPP','mrp'])]
dup8
# Out:
#                  generic_name    form dose_size/strength manufacturer_name  \
# 23                 Filgrastim  FOR105             300MCG      INTAS PHARMA
# 62            Povidone-iodine  FOR106              2%W/V      WIN MEDICARE
# 159     Ibuprofen+paracetamol  FOR118      100MG+162.5MG             CIPLA
# 247               Paracetamol  FOR118              250MG        MICRO LABS
# 303               Paracetamol  FOR114              100MG   GLAXOSMITHKLINE
# ...                       ...     ...                ...               ...
# 271265            Vessel Loop  FOR154                NaN            PRYMAX
# 271298              Telescope  FOR154                NaN        KARL STORZ
# 271303    Thermometer Digital  FOR154                NaN             LOCAL
# 271411  Skin Care Preparation  FOR113               Null       USV PVT LTD
# 271443             Metoprolol  FOR102               50MG       ASTRAZENECA
#
#                  subcategory_name  unit_per_pack/UPP       mrp
# ...

# %%
dup8=dup8.drop_duplicates('form',keep='last')
dup8
# Out:
#                                              generic_name    form  \
# 2205                                          Propranolol  FOR136
# 29371                                       Beclometasone  FOR151
# 32880                            Clindamycin+clotrimazole  FOR125
# 78631                     Glimepiride+metformin+voglibose  FOR117
# 99645                                        Luliconazole  FOR119
# 138524                         Difluprednate+Moxifloxacin  FOR144
# 175729                            Metformin+Teneligliptin  FOR127
# 175846                              Formoterol+tiotropium  FOR152
# 196401           Ambroxol+guaifenesin+menthol+terbutaline  FOR145
# 239434                            Sweet & Salted Biscuits  FOR143
# 249527                                               Balm  FOR101
# 250090                                        Tooth Paste  FOR112
# 250094                                        Tooth Paste  FOR103
# ...

# %%
dup8.to_csv('rule8.csv')

# %% [markdown]
# # Rule9: Not Duplicate records.

# %%
dup9 = y[y.duplicated(['generic_name','dose_size/strength','manufacturer_name','subcategory_name',])]
dup9
# Out:
#                   generic_name    form dose_size/strength manufacturer_name  \
# 21                Ademetionine  FOR102              200MG        SUN PHARMA
# 22                Ademetionine  FOR102              400MG        SUN PHARMA
# 23                  Filgrastim  FOR105             300MCG      INTAS PHARMA
# 45      Nutritional Supplement  FOR110               15GM    FRESENIUS KABI
# 62             Povidone-iodine  FOR106              2%W/V      WIN MEDICARE
# ...                        ...     ...                ...               ...
# 271433       Absorbable Suture  FOR154             Jan-00           ETHICON
# 271442            Promethazine  FOR102               25MG            ABBOTT
# 271443              Metoprolol  FOR102               50MG       ASTRAZENECA
# 271446         Surgical Drapes  FOR154                NaN        MEDI KARMA
# 271447         Surgical Drapes  FOR154                NaN        MEDI KARMA
#
# ...

# %%
dup9=dup9.drop_duplicates(['unit_per_pack/UPP','mrp'],keep='last')
dup9
# Out:
#                  generic_name    form dose_size/strength manufacturer_name  \
# 21               Ademetionine  FOR102              200MG        SUN PHARMA
# 22               Ademetionine  FOR102              400MG        SUN PHARMA
# 23                 Filgrastim  FOR105             300MCG      INTAS PHARMA
# 72                Toothpastes  FOR112                  0    DR REDDYS LABS
# 159     Ibuprofen+paracetamol  FOR118      100MG+162.5MG             CIPLA
# ...                       ...     ...                ...               ...
# 271433      Absorbable Suture  FOR154             Jan-00           ETHICON
# 271442           Promethazine  FOR102               25MG            ABBOTT
# 271443             Metoprolol  FOR102               50MG       ASTRAZENECA
# 271446        Surgical Drapes  FOR154                NaN        MEDI KARMA
# 271447        Surgical Drapes  FOR154                NaN        MEDI KARMA
#
#                  subcategory_name  unit_per_pack/UPP      mrp
# ...

# %%
dup9.to_csv('rule9.csv')

# %%
len(y)
# Out:
# 271454

# %% [markdown]
# # Removes I set of duplicates

# %%
y=y[~y.isin(dup1)].dropna()

# %%
len(y)
# Out:
# 250270

# %%
y=y[~y.isin(dup5)].dropna()

# %%
len(y)
# Out:
# 244726

# %%
y=y[~y.isin(dup8)].dropna()

# %%
len(y)
# Out:
# 244717

# %% [markdown]
# # Find list of unique values

# %%
x = x.loc[y.index, :]

# %%
len(x)
# Out:
# 244717

# %%
x.nunique()
# Out:
# Unnamed: 0                   244717
# _id                          244717
# stratmed_sku                 244717
# brand_code                        0
# brand_name                   241842
# category                          5
# committed_volume                  0
# dose_size/strength            23576
# dpco_list                         5
# form                             62
# generic_name                  31057
# group                          1127
# gst                               7
# manufacturer_code              7203
# mrp                           28527
# price_effective_from_date         2
# price_effective_to_date           2
# purchase_price_w_gst              1
# remarks                           1
# roa                               9
# status                            1
# subcategory                      75
# therapy_code                     29
# unit_per_pack/UPP                76
# uom_pack_type                    60
# business_unit                   111
# ...

# %%
x.to_csv('final_stratmed.csv')
